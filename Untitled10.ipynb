# %% [markdown]
# <a href="https://colab.research.google.com/github/Harini0305/Algorithms/blob/main/Untitled10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import matplotlib.pyplot as plt

def binary_search(arr, low, high, x):
    if high >= low:
        mid = (high + low) // 2
        if arr[mid] == x:
            return mid
        elif arr[mid] > x:
            return binary_search(arr, low, mid - 1, x)
        else:
            return binary_search(arr, mid + 1, high, x)
    else:
        return -1

def measure_time(n, x):
    arr = list(range(n))
    start_time = time.time()
    binary_search(arr, 0, len(arr) - 1, x)
    end_time = time.time()
    return end_time - start_time

n_values = [10, 100, 1000, 5000, 10000, 50000, 100000]
times = []

for n in n_values:
    x = n // 2
    times.append(measure_time(n, x))

plt.plot(n_values, times)
plt.xlabel('Number of elements (n)')
plt.ylabel('Time (seconds)')
plt.title('Time taken for Recursive Binary Search')
plt.show()
