# %% [markdown]
# <a href="https://colab.research.google.com/github/Harini0305/Algorithms/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import time
import random
import matplotlib.pyplot as plt

def linear_search(arr, target):
    for i in range(len(arr)):
        if arr[i] == target:
            return i
    return -1

def measure_time(n, target):
    arr = [random.randint(1, 10000) for _ in range(n)]
    start_time = time.time()
    linear_search(arr, target)
    end_time = time.time()
    return end_time - start_time

n_values = [10, 100, 500, 1000, 5000, 10000, 20000, 50000]
times = []

target = 5000
for n in n_values:
    time_taken = measure_time(n, target)
    times.append(time_taken)

plt.plot(n_values, times, marker='o')
plt.title('Linear Search: Time Taken vs n (Number of Elements)')
plt.xlabel('n (Number of Elements)')
plt.ylabel('Time Taken (seconds)')
plt.grid(True)
plt.show()
